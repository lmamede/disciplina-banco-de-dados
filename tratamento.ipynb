# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv('games.csv')

df1.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2022    1610612740     126.0        0.484        0.926  ...      25.0
# 1    2022    1610612762     120.0        0.488        0.952  ...      16.0
# 2    2022    1610612739     114.0        0.482        0.786  ...      22.0
# 3    2022    1610612755     113.0        0.441        0.909  ...      27.0
# 4    2022    1610612737     108.0        0.429        1.000  ...      22.0
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26651 entries, 0 to 26650
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     26651 non-null  object
#  1   GAME_ID           26651 non-null  int64
#  2   GAME_STATUS_TEXT  26651 non-null  object
#  3   HOME_TEAM_ID      26651 non-null  int64
#  4   VISITOR_TEAM_ID   26651 non-null  int64
#  5   SEASON            26651 non-null  int64
#  6   TEAM_ID_home      26651 non-null  int64
#  7   PTS_home          26552 non-null  float64
#  8   FG_PCT_home       26552 non-null  float64
#  9   FT_PCT_home       26552 non-null  float64
#  10  FG3_PCT_home      26552 non-null  float64
#  11  AST_home          26552 non-null  float64
#  12  REB_home          26552 non-null  float64
#  13  TEAM_ID_away      26651 non-null  int64
#  14  PTS_away          26552 non-null  float64
#  15  FG_PCT_away       26552 non-null  float64
# ...

# %%
df1.describe()
# Out:
#             GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        SEASON  \
# count  2.665100e+04  2.665100e+04     2.665100e+04  26651.000000
# mean   2.175487e+07  1.610613e+09     1.610613e+09   2012.113879
# std    5.570189e+06  8.638670e+00     8.659299e+00      5.587031
# min    1.030000e+07  1.610613e+09     1.610613e+09   2003.000000
# 25%    2.070001e+07  1.610613e+09     1.610613e+09   2007.000000
# 50%    2.120076e+07  1.610613e+09     1.610613e+09   2012.000000
# 75%    2.180005e+07  1.610613e+09     1.610613e+09   2017.000000
# max    5.210021e+07  1.610613e+09     1.610613e+09   2022.000000
#
#        TEAM_ID_home      PTS_home   FG_PCT_home   FT_PCT_home  FG3_PCT_home  \
# count  2.665100e+04  26552.000000  26552.000000  26552.000000  26552.000000
# mean   1.610613e+09    103.455898      0.460735      0.760377      0.356023
# std    8.638670e+00     13.283370      0.056676      0.100677      0.111164
# ...

# %%
df1.drop_duplicates(subset=['GAME_ID'], keep='first', inplace=True)

# %%
columns_game = ['GAME_ID', 'GAME_DATE_EST', 'GAME_STATUS_TEXT', 'SEASON', 'HOME_TEAM_WINS', 'HOME_TEAM_ID', 'VISITOR_TEAM_ID']

# %%
df1[columns_game].head()
# Out:
#     GAME_ID GAME_DATE_EST GAME_STATUS_TEXT  SEASON  HOME_TEAM_WINS  \
# 0  22200477    2022-12-22            Final    2022               1
# 1  22200478    2022-12-22            Final    2022               1
# 2  22200466    2022-12-21            Final    2022               1
# 3  22200467    2022-12-21            Final    2022               1
# 4  22200468    2022-12-21            Final    2022               0
#
#    HOME_TEAM_ID  VISITOR_TEAM_ID
# 0    1610612740       1610612759
# 1    1610612762       1610612764
# 2    1610612739       1610612749
# 3    1610612755       1610612765
# 4    1610612737       1610612741

# %%
with open('games.sql', 'w') as writer:
    for id in df1.index:

        writer.write('INSERT INTO Game VALUES (')
        
        for i in range(len(columns_game)):
            column = columns_game[i]

            value = df1[column][id]

            if type(value)==str:
                writer.write('\'')

                writer.write(value)
        
                writer.write('\'')
            else:
                if pd.isna(value):
                    writer.write('NULL')
                elif type(value)==int:
                    value = int(value)
                    writer.write(str(value))
                else:
                    writer.write(str(value))
            

            if i == len(columns_game)-1:
                writer.write(')')
            else:
                writer.write(', ')

    
        writer.write(';\n')

# %%
columns_home = ['REB_home', 'AST_home', 'FG3_PCT_home', 'FT_PCT_home', 'FG_PCT_home', 'PTS_home', 'TEAM_ID_home', 'GAME_ID']

# %%
columns_away = ['REB_away', 'AST_away', 'FG3_PCT_away', 'FT_PCT_away', 'FG_PCT_away', 'PTS_away', 'TEAM_ID_away', 'GAME_ID']

# %%
to_int = ['REB_home', 'AST_home', 'PTS_home', 'REB_away', 'AST_away', 'PTS_away']

# %%
for i in to_int:
    df1[i] = df1[i].astype('Int64')

# %%
df1[columns_home].head()
# Out:
#    REB_home  AST_home  FG3_PCT_home  FT_PCT_home  FG_PCT_home  PTS_home  \
# 0        46        25         0.382        0.926        0.484       126
# 1        40        16         0.457        0.952        0.488       120
# 2        37        22         0.313        0.786        0.482       114
# 3        49        27         0.297        0.909        0.441       113
# 4        47        22         0.378        1.000        0.429       108
#
#    TEAM_ID_home   GAME_ID
# 0    1610612740  22200477
# 1    1610612762  22200478
# 2    1610612739  22200466
# 3    1610612755  22200467
# 4    1610612737  22200468

# %%
with open('teamst.sql', 'w') as writer:
    for id in df1.index:

        writer.write('INSERT INTO TeamStatistics VALUES (')
        
        for i in range(len(columns_home)):
            column = columns_home[i]

            value = df1[column][id]

            if type(value)==str:
                writer.write('\'')

                writer.write(value)
        
                writer.write('\'')
            else:
                if pd.isna(value):
                    writer.write('NULL')
                elif type(value)==int:
                    value = int(value)
                    writer.write(str(value))
                else:
                    writer.write(str(value))
            

            if i == len(columns_home)-1:
                writer.write(')')
            else:
                writer.write(', ')

    
        writer.write(';\n')

        writer.write('INSERT INTO TeamStatistics VALUES (')

        for i in range(len(columns_away)):
            column = columns_away[i]

            value = df1[column][id]

            if type(value)==str:
                writer.write('\'')

                writer.write(value)
        
                writer.write('\'')
            else:
                if pd.isna(value):
                    writer.write('NULL')
                elif type(value)==int:
                    value = int(value)
                    writer.write(str(value))
                else:
                    writer.write(str(value))
            

            if i == len(columns_away)-1:
                writer.write(')')
            else:
                writer.write(', ')

    
        writer.write(';\n')

# %%
df2 = pd.read_csv('games_details.csv')

df2.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  DREB  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0   1.0
# 1   Jeremy Sochan   Jeremy              F     NaN  31:01  ...   6.0   3.0
# 2    Jakob Poeltl    Jakob              C     NaN  21:42  ...   1.0   3.0
# 3   Devin Vassell    Devin              G     NaN  30:20  ...   0.0   9.0
# 4       Tre Jones      Tre              G     NaN  27:44  ...   0.0   2.0
#
#    REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0  2.0  0.0  1.0  0.0  2.0  5.0   2.0        -2.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668628 entries, 0 to 668627
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   GAME_ID            668628 non-null  int64
#  1   TEAM_ID            668628 non-null  int64
#  2   TEAM_ABBREVIATION  668628 non-null  object
#  3   TEAM_CITY          668628 non-null  object
#  4   PLAYER_ID          668628 non-null  int64
#  5   PLAYER_NAME        668628 non-null  object
#  6   NICKNAME           53037 non-null   object
#  7   START_POSITION     255765 non-null  object
#  8   COMMENT            109689 non-null  object
#  9   MIN                558938 non-null  object
#  10  FGM                558938 non-null  float64
#  11  FGA                558938 non-null  float64
#  12  FG_PCT             558938 non-null  float64
#  13  FG3M               558938 non-null  float64
#  14  FG3A               558938 non-null  float64
# ...

# %%
df2.describe()
# Out:
#             GAME_ID       TEAM_ID     PLAYER_ID            FGM            FGA  \
# count  6.686280e+05  6.686280e+05  6.686280e+05  558938.000000  558938.000000
# mean   2.171771e+07  1.610613e+09  4.013434e+05       3.588446       7.896652
# std    5.656289e+06  8.652260e+00  7.225618e+06       3.030466       5.677002
# min    1.030000e+07  1.610613e+09  1.500000e+01       0.000000       0.000000
# 25%    2.070003e+07  1.610613e+09  2.466000e+03       1.000000       3.000000
# 50%    2.120096e+07  1.610613e+09  2.011810e+05       3.000000       7.000000
# 75%    2.180014e+07  1.610613e+09  2.034710e+05       5.000000      11.000000
# max    5.210021e+07  1.610613e+09  1.962938e+09      28.000000      50.000000
#
#               FG_PCT           FG3M           FG3A        FG3_PCT  \
# count  558938.000000  558938.000000  558938.000000  558938.000000
# mean        0.416842       0.778117       2.186019       0.201032
# std         0.251913       1.227615       2.569913       0.289685
# ...

# %%
def treat(x):
    pos = -1

    sec = 0

    for i in range(len(x)):
        if x[i] == ':':
            pos = i
            break

    if pos!=-1:
        sec = int(x[pos+1:])

        minu = float(x[:pos])

        minu = int(minu)

        sec+=minu*60

    else:
        minu = int(x)
        minu = abs(minu)

        sec = minu*60
    
    return sec

# %%
nicks = {}
minutes = {}

for idx in df2.index:
    id = df2['PLAYER_ID'][idx]
    nick = df2['NICKNAME'][idx]
    minu = df2['MIN'][idx]

    if id in nicks:
        if pd.isna(nicks[id]) and pd.isna(nick)==0:
            nicks[id] = nick
    else:
        nicks[id] = nick
    
    if id in minutes:
        if pd.isna(minu)==0:
            minutes[id] += treat(minu)
    else:
        if pd.isna(minu)==0:
            minutes[id] = treat(minu)
        else:
            minutes[id] = 0

# %%
df3 = pd.read_csv('players.csv')

df3.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7228 entries, 0 to 7227
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PLAYER_NAME  7228 non-null   object
#  1   TEAM_ID      7228 non-null   int64
#  2   PLAYER_ID    7228 non-null   int64
#  3   SEASON       7228 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 226.0+ KB

# %%
df3.describe()
# Out:
#             TEAM_ID     PLAYER_ID       SEASON
# count  7.228000e+03  7.228000e+03  7228.000000
# mean   1.610613e+09  2.355862e+06  2014.159934
# std    8.723521e+00  6.106688e+07     3.126216
# min    1.610613e+09  2.440000e+02  2009.000000
# 25%    1.610613e+09  2.007680e+05  2012.000000
# 50%    1.610613e+09  2.023465e+05  2014.000000
# 75%    1.610613e+09  2.039100e+05  2017.000000
# max    1.610613e+09  1.962938e+09  2019.000000

# %%
columns_includes = ['TEAM_ID', 'PLAYER_ID', 'SEASON']

# %%
with open('includes.sql', 'w') as writer:
    for id in df3.index:

        writer.write('INSERT INTO Includes VALUES (')
        
        for i in range(len(columns_includes)):
            column = columns_includes[i]

            value = df3[column][id]

            if type(value)==str:
                writer.write('\'')

                writer.write(value)
        
                writer.write('\'')
            else:
                if pd.isna(value):
                    writer.write('NULL')
                elif type(value)==int:
                    value = int(value)
                    writer.write(str(value))
                else:
                    writer.write(str(value))
            

            if i == len(columns_includes)-1:
                writer.write(')')
            else:
                writer.write(', ')

    
        writer.write(';\n')

# %%
nomes = {}

# %%
for idx in df3.index:
    id = df3['PLAYER_ID'][idx]
    name = df3['PLAYER_NAME'][idx]
    
    if id in nomes:
        if name != nomes[id]:
            print(name, nomes[id])

    nomes[id] = name

# %%
ids = list(nomes.keys())

nomes = list(nomes.values())

# %%
data = {'PLAYER_ID': ids, 'PLAYER_NAME':nomes}

df = pd.DataFrame(data)

# %%
def ni(x):
    if x in nicks:
        return nicks[x]
    else:
        return pd.NA

# %%
def sec(x):
    if x in minutes:
        return minutes[x]
    else:
        return 0

# %%
df.head()
# Out:
#    PLAYER_ID       PLAYER_NAME
# 0    1626220     Royce O'Neale
# 1     202711  Bojan Bogdanovic
# 2     203497       Rudy Gobert
# 3    1628378  Donovan Mitchell
# 4     201144       Mike Conley

# %%
df['NICKNAME'] = df['PLAYER_ID'].apply(ni)

# %%
df['SECONDS_PLAYED'] = df['PLAYER_ID'].apply(sec)

# %%
df.head()
# Out:
#    PLAYER_ID       PLAYER_NAME NICKNAME  SECONDS_PLAYED
# 0    1626220     Royce O'Neale    Royce          737123
# 1     202711  Bojan Bogdanovic    Bojan         1242080
# 2     203497       Rudy Gobert     Rudy         1302063
# 3    1628378  Donovan Mitchell  Donovan          880513
# 4     201144       Mike Conley     Mike         2143841

# %%
columns_player = ['PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'SECONDS_PLAYED']

# %%
with open('players.sql', 'w') as writer:
    for id in df.index:

        writer.write('INSERT INTO Player VALUES (')
        
        for i in range(len(columns_player)):
            column = columns_player[i]

            value = df[column][id]

            if type(value)==str:
                writer.write('\'')

                for c in range(len(value)):
                    if value[c] == '\'':
                        writer.write("''")
                    else:
                        writer.write(value[c])
                    
                
                writer.write('\'')
            else:
                if pd.isna(value):
                    writer.write('NULL')
                elif type(value)==int:
                    value = int(value)
                    writer.write(str(value))
                else:
                    writer.write(str(value))
            

            if i == len(columns_player)-1:
                writer.write(')')
            else:
                writer.write(', ')

    
        writer.write(';\n')

# %%
df4 = pd.read_csv('ranking.csv')

df4.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G  \
# 0  1610612743          0      22022    2022-12-22       West       Denver  30
# 1  1610612763          0      22022    2022-12-22       West      Memphis  30
# 2  1610612740          0      22022    2022-12-22       West  New Orleans  31
# 3  1610612756          0      22022    2022-12-22       West      Phoenix  32
# 4  1610612746          0      22022    2022-12-22       West  LA Clippers  33
#
#     W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  19  11  0.633        10-3         9-8           NaN
# 1  19  11  0.633        13-2         6-9           NaN
# 2  19  12  0.613        13-4         6-8           NaN
# 3  19  13  0.594        14-4         5-9           NaN
# 4  19  14  0.576        11-7         8-7           NaN

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210342 entries, 0 to 210341
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TEAM_ID        210342 non-null  int64
#  1   LEAGUE_ID      210342 non-null  int64
#  2   SEASON_ID      210342 non-null  int64
#  3   STANDINGSDATE  210342 non-null  object
#  4   CONFERENCE     210342 non-null  object
#  5   TEAM           210342 non-null  object
#  6   G              210342 non-null  int64
#  7   W              210342 non-null  int64
#  8   L              210342 non-null  int64
#  9   W_PCT          210342 non-null  float64
#  10  HOME_RECORD    210342 non-null  object
#  11  ROAD_RECORD    210342 non-null  object
#  12  RETURNTOPLAY   3990 non-null    float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 20.9+ MB

# %%
df4.describe()
# Out:
#             TEAM_ID  LEAGUE_ID      SEASON_ID              G              W  \
# count  2.103420e+05   210342.0  210342.000000  210342.000000  210342.000000
# mean   1.610613e+09        0.0   21401.054773      56.659735      28.333357
# std    8.641501e+00        0.0    2395.250417      28.644294      17.268500
# min    1.610613e+09        0.0   12003.000000       0.000000       0.000000
# 25%    1.610613e+09        0.0   22006.000000      32.000000      14.000000
# 50%    1.610613e+09        0.0   22011.000000      67.000000      28.000000
# 75%    1.610613e+09        0.0   22017.000000      82.000000      42.000000
# max    1.610613e+09        0.0   22022.000000      82.000000      73.000000
#
#                    L          W_PCT  RETURNTOPLAY
# count  210342.000000  210342.000000   3990.000000
# mean       28.326378       0.492833      0.600000
# std        17.260557       0.187763      0.489959
# min         0.000000       0.000000      0.000000
# ...

# %%
df4.drop_duplicates(subset=['SEASON_ID', 'TEAM_ID'], keep='first', inplace=True)

# %%
teams = {}

# %%
for idx in df4.index:
    id = df4['TEAM_ID'][idx]

    nome_time = df4['TEAM'][idx]

    teams[id] = nome_time

# %%
columns_ranking = ['SEASON_ID', 'W_PCT', 'W', 'L', 'G', 'CONFERENCE', 'TEAM_ID']

# %%
df4[columns_ranking].head()
# Out:
#    SEASON_ID  W_PCT   W   L   G CONFERENCE     TEAM_ID
# 0      22022  0.633  19  11  30       West  1610612743
# 1      22022  0.633  19  11  30       West  1610612763
# 2      22022  0.613  19  12  31       West  1610612740
# 3      22022  0.594  19  13  32       West  1610612756
# 4      22022  0.576  19  14  33       West  1610612746

# %%
with open('season.sql', 'w') as writer:
    for id in df4.index:

        writer.write('INSERT INTO SeasonStatistics VALUES (')
        
        for i in range(len(columns_ranking)):
            column = columns_ranking[i]

            value = df4[column][id]

            if type(value)==str:
                writer.write('\'')

                writer.write(value)
                    
                writer.write('\'')
            else:
                if pd.isna(value):
                    writer.write('NULL')
                elif type(value)==int:
                    value = int(value)
                    writer.write(str(value))
                else:
                    writer.write(str(value))
            

            if i == len(columns_ranking)-1:
                writer.write(')')
            else:
                writer.write(', ')

    
        writer.write(';\n')

# %%
df5 = pd.read_csv('teams.csv')

df5.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   LEAGUE_ID           30 non-null     int64
#  1   TEAM_ID             30 non-null     int64
#  2   MIN_YEAR            30 non-null     int64
#  3   MAX_YEAR            30 non-null     int64
#  4   ABBREVIATION        30 non-null     object
#  5   NICKNAME            30 non-null     object
#  6   YEARFOUNDED         30 non-null     int64
#  7   CITY                30 non-null     object
#  8   ARENA               30 non-null     object
#  9   ARENACAPACITY       26 non-null     float64
#  10  OWNER               30 non-null     object
#  11  GENERALMANAGER      30 non-null     object
#  12  HEADCOACH           30 non-null     object
#  13  DLEAGUEAFFILIATION  30 non-null     object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 3.4+ KB

# %%
df5.describe()
# Out:
#        LEAGUE_ID       TEAM_ID     MIN_YEAR  MAX_YEAR  YEARFOUNDED  \
# count       30.0  3.000000e+01    30.000000      30.0    30.000000
# mean         0.0  1.610613e+09  1969.700000    2019.0  1969.700000
# std          0.0  8.803408e+00    16.698441       0.0    16.698441
# min          0.0  1.610613e+09  1946.000000    2019.0  1946.000000
# 25%          0.0  1.610613e+09  1952.000000    2019.0  1952.000000
# 50%          0.0  1.610613e+09  1970.000000    2019.0  1970.000000
# 75%          0.0  1.610613e+09  1979.000000    2019.0  1979.000000
# max          0.0  1.610613e+09  2002.000000    2019.0  2002.000000
#
#        ARENACAPACITY
# count      26.000000
# mean    18553.307692
# std      3916.923362
# min         0.000000
# 25%     18641.500000
# 50%     19131.000000
# 75%     19790.750000
# max     21711.000000

# %%
df_arena = df5.copy()

# %%
df_arena.drop_duplicates(subset=['ARENA'], keep='first', inplace=True)

# %%
columns_arena = ['ARENA', 'ARENACAPACITY']

# %%
df_arena[columns_arena]
# Out:
#                          ARENA  ARENACAPACITY
# 0             State Farm Arena        18729.0
# 1                    TD Garden        18624.0
# 2         Smoothie King Center            NaN
# 3                United Center        21711.0
# 4     American Airlines Center        19200.0
# 5                 Pepsi Center        19099.0
# 6                Toyota Center        18104.0
# 7               Staples Center        19060.0
# 9       AmericanAirlines Arena        19600.0
# 10                Fiserv Forum        17500.0
# 11               Target Center        19356.0
# 12             Barclays Center            NaN
# 13       Madison Square Garden        19763.0
# 14                Amway Center            0.0
# 15     Bankers Life Fieldhouse        18345.0
# 16          Wells Fargo Center            NaN
# 17  Talking Stick Resort Arena            NaN
# 18                 Moda Center        19980.0
# 19             Golden 1 Center        17500.0
# ...

# %%
df_arena['ARENACAPACITY'] = df_arena['ARENACAPACITY'].astype('Int64')

# %%
cap = {
    'Smoothie King Center': 17791,
    'Barclays Center': 19000,
    'Wells Fargo Center': 21000,
    'Talking Stick Resort Arena': 18422,
    'Amway Center': 20000
}

# %%
with open('arena.sql', 'w') as writer:
    for id in df_arena.index:

        writer.write('INSERT INTO Arena VALUES (')
        
        for i in range(len(columns_arena)):
            column = columns_arena[i]

            value = df_arena[column][id]

            if type(value)==str:
                writer.write('\'')

                writer.write(value)
            
                writer.write('\'')
            else:
                if pd.isna(value) or value==0:
                    value = cap[df_arena['ARENA'][id]]
                
                if type(value)==int:
                    value = int(value)
                    
                    writer.write(str(value))
                else:
                    writer.write(str(value))
            

            if i == len(columns_arena)-1:
                writer.write(')')
            else:
                writer.write(', ')

    
        writer.write(';\n')

# %%
def name_time(x):
    return teams[x]

# %%
df5['NAME'] = df5['TEAM_ID'].apply(name_time)

# %%
columns_team = ['TEAM_ID', 'ABBREVIATION', 'CITY', 'NICKNAME', 'MAX_YEAR', 'MIN_YEAR', 'YEARFOUNDED', 'NAME', 'ARENA']

# %%
df5[columns_team].head()
# Out:
#       TEAM_ID ABBREVIATION         CITY   NICKNAME  MAX_YEAR  MIN_YEAR  \
# 0  1610612737          ATL      Atlanta      Hawks      2019      1949
# 1  1610612738          BOS       Boston    Celtics      2019      1946
# 2  1610612740          NOP  New Orleans   Pelicans      2019      2002
# 3  1610612741          CHI      Chicago      Bulls      2019      1966
# 4  1610612742          DAL       Dallas  Mavericks      2019      1980
#
#    YEARFOUNDED         NAME                     ARENA
# 0         1949      Atlanta          State Farm Arena
# 1         1946       Boston                 TD Garden
# 2         2002  New Orleans      Smoothie King Center
# 3         1966      Chicago             United Center
# 4         1980       Dallas  American Airlines Center

# %%
with open('teams.sql', 'w') as writer:
    for id in df5.index:

        writer.write('INSERT INTO Team VALUES (')
        
        for i in range(len(columns_team)):
            column = columns_team[i]

            value = df5[column][id]

            if type(value)==str:
                writer.write('\'')

                writer.write(value)
            
                writer.write('\'')
            else:
                if pd.isna(value):
                    writer.write('NULL')
                elif type(value)==int:
                    value = int(value)
                    writer.write(str(value))
                else:
                    writer.write(str(value))
            

            if i == len(columns_team)-1:
                writer.write(')')
            else:
                writer.write(', ')

    
        writer.write(';\n')
